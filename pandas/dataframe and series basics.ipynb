# %%
import pandas as pd

# %%
people = {
    "fist":['sanjai','sanju'],
    'last':['sanju','sanjai'],
    'email':['sanjai@gmail.com','sanju@gmail.com'],
    'count':['1','2']
}

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#      fist    last             email count
# 0  sanjai   sanju  sanjai@gmail.com     1
# 1   sanju  sanjai   sanju@gmail.com     2

# %%
df['email']
# Out:
# 0    sanjai@gmail.com
# 1     sanju@gmail.com
# Name: email, dtype: object

# %%
df.email
# Out:
# 0    sanjai@gmail.com
# 1     sanju@gmail.com
# Name: email, dtype: object

# %% [markdown]
# #COUNT IS A KEYWORD WE SHOULD NOT USE IT AS COLUMN NAME

# %%
df.count
# Out:
# <bound method DataFrame.count of      fist    last             email count
# 0  sanjai   sanju  sanjai@gmail.com     1
# 1   sanju  sanjai   sanju@gmail.com     2>

# %%
df[['last','count']]
# Out:
#      last count
# 0   sanju     1
# 1  sanjai     2

# %%
df.columns
# Out:
# Index(['fist', 'last', 'email', 'count'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2, step=1)

# %%
df = pd.read_csv("C:/Users/ASUS/Desktop/python(ml)/data/survey_results_public.csv")
pd.set_option('display.max_columns',None)

# %%
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %%
pd.set_option('display.expand_frame_repr', False)

# %%
print(df.columns)
# Out:
# Index(['ResponseId', 'MainBranch', 'Age', 'Employment', 'RemoteWork', 'Check',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        ...
#        'JobSatPoints_6', 'JobSatPoints_7', 'JobSatPoints_8', 'JobSatPoints_9',
#        'JobSatPoints_10', 'JobSatPoints_11', 'SurveyLength', 'SurveyEase',
#        'ConvertedCompYearly', 'JobSat'],
#       dtype='object', length=114)

# %% [markdown]
# #LOC AND ILOC

# %%
df.iloc[[0,4]]
# Out:
#    ResponseId                      MainBranch                 Age           Employment RemoteWork   Check CodingActivities                                            EdLevel                                          LearnCode                                    LearnCodeOnline                                            TechDoc YearsCode YearsCodePro                DevType OrgSize PurchaseInfluence BuyNewTool BuildvsBuy TechEndorse                   Country Currency  CompTotal                   LanguageHaveWorkedWith              LanguageWantToWorkWith                     LanguageAdmired DatabaseHaveWorkedWith DatabaseWantToWorkWith    DatabaseAdmired PlatformHaveWorkedWith PlatformWantToWorkWith PlatformAdmired WebframeHaveWorkedWith WebframeWantToWorkWith WebframeAdmired   EmbeddedHaveWorkedWith EmbeddedWantToWorkWith    EmbeddedAdmired MiscTechHaveWorkedWith MiscTechWantToWorkWith MiscTechAdmired ToolsTechHaveWorkedWith ToolsTechWantToWorkWith ToolsTechAdmired NEWCollabToolsHaveWorke
# ...

# %%
df.loc[[0,5]]
# Out:
#    ResponseId                      MainBranch                 Age           Employment RemoteWork   Check CodingActivities                    EdLevel                                          LearnCode LearnCodeOnline TechDoc YearsCode YearsCodePro  DevType OrgSize PurchaseInfluence BuyNewTool BuildvsBuy TechEndorse                   Country Currency  CompTotal                             LanguageHaveWorkedWith                             LanguageWantToWorkWith                                    LanguageAdmired DatabaseHaveWorkedWith DatabaseWantToWorkWith  DatabaseAdmired PlatformHaveWorkedWith PlatformWantToWorkWith PlatformAdmired WebframeHaveWorkedWith WebframeWantToWorkWith WebframeAdmired EmbeddedHaveWorkedWith EmbeddedWantToWorkWith EmbeddedAdmired MiscTechHaveWorkedWith MiscTechWantToWorkWith MiscTechAdmired       ToolsTechHaveWorkedWith ToolsTechWantToWorkWith       ToolsTechAdmired       NEWCollabToolsHaveWorkedWith       NEWCollabToolsWantToWorkWith              NEWCollabTo
# ...

# %% [markdown]
# #FOR COLUMNS

# %%
df.iloc[[0,4],1]
# Out:
# 0    I am a developer by profession
# 4    I am a developer by profession
# Name: MainBranch, dtype: object

# %% [markdown]
# THE ONLY DIFFERENCE BW ILOC AND LOC IS LOC SUPPORTS LABELS and iloc supports indexes

# %%
df.loc[[0,4],'MainBranch']
# Out:
# 0    I am a developer by profession
# 4    I am a developer by profession
# Name: MainBranch, dtype: object

# %%
df.loc[[1,4],1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 df.loc[[1,4],[1]]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexing.py:1375, in _LocIndexer._getitem_tuple(self, tup)
#    1373 # ugly hack for GH #836
#    1374 if self._multi_take_opportunity(tup):
# -> 1375     return self._multi_take(tup)
#    1377 return self._getitem_tuple_same_dim(tup)
#
# ...

# %% [markdown]
# #SLICING USING ILOC AND LOC

# %%
df.iloc[0:4]
# Out:
#    ResponseId                      MainBranch                 Age           Employment RemoteWork   Check                                   CodingActivities                                            EdLevel                                          LearnCode                                    LearnCodeOnline                                            TechDoc YearsCode YearsCodePro                DevType OrgSize PurchaseInfluence BuyNewTool BuildvsBuy TechEndorse                                            Country Currency  CompTotal                             LanguageHaveWorkedWith                             LanguageWantToWorkWith                                    LanguageAdmired           DatabaseHaveWorkedWith      DatabaseWantToWorkWith             DatabaseAdmired                    PlatformHaveWorkedWith                    PlatformWantToWorkWith                           PlatformAdmired                  WebframeHaveWorkedWith            WebframeWantToWorkWith               Webf
# ...

# %%
df.loc[0:4]
# Out:
#    ResponseId                      MainBranch                 Age           Employment RemoteWork   Check                                   CodingActivities                                            EdLevel                                          LearnCode                                    LearnCodeOnline                                            TechDoc YearsCode YearsCodePro                DevType OrgSize PurchaseInfluence BuyNewTool BuildvsBuy TechEndorse                                            Country Currency  CompTotal                             LanguageHaveWorkedWith                             LanguageWantToWorkWith                                    LanguageAdmired           DatabaseHaveWorkedWith      DatabaseWantToWorkWith             DatabaseAdmired                    PlatformHaveWorkedWith                    PlatformWantToWorkWith                           PlatformAdmired                  WebframeHaveWorkedWith            WebframeWantToWorkWith               Webf
# ...

# %%
df.iloc[0:4,0:2]
# Out:
#    ResponseId                      MainBranch
# 0           1  I am a developer by profession
# 1           2  I am a developer by profession
# 2           3  I am a developer by profession
# 3           4           I am learning to code

# %%
df.loc[0:4,0:2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 df.loc[0:4,0:2]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexing.py:1377, in _LocIndexer._getitem_tuple(self, tup)
#    1374 if self._multi_take_opportunity(tup):
#    1375     return self._multi_take(tup)
# -> 1377 return self._getitem_tuple_same_dim(tup)
#
# ...

# %%
df.loc[0:4,'ResponseId':'Age']
# Out:
#    ResponseId                      MainBranch                 Age
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old

# %% [markdown]
# BASICALLY SLICING IN PYTHON WORKS BY N-1 BUT HERE IT DOES NOT DO THAT IT TAKES TILL THE N

# %% [markdown]
# COUNTING

# %%
df.Age.value_counts()
# Out:
# Age
# 25-34 years old       23911
# 35-44 years old       14942
# 18-24 years old       14098
# 45-54 years old        6249
# 55-64 years old        2575
# Under 18 years old     2568
# 65 years or older       772
# Prefer not to say       322
# Name: count, dtype: int64
